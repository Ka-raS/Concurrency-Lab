# %% [markdown]
# # Part 1: Creating Concurrent Processes
#
# Objective: Create two concurrent processes that run in parallel and print numbers.
#
# Steps:
# 1. Create a Python program where you spawn two processes.
# 2. Each process should print numbers from 1 to 5, with a delay between each print statement.
# 3. The output should show interleaving of the two processes' prints.

# %%
import threading
import time

def print_numbers(name, delay):
    for i in range(1, 6):
        print(f"Thread {name} printing {i}")
        time.sleep(delay)

thread0 = threading.Thread(target=print_numbers, args=(0, 0.02))
thread1 = threading.Thread(target=print_numbers, args=(1, 0.04))

thread0.start()
thread1.start()

thread0.join()
thread1.join()
# Out:
# Thread 0 printing 1
# Thread 1 printing 1
# Thread 0 printing 2
# Thread 0 printing 3
# Thread 1 printing 2
# Thread 0 printing 4
# Thread 0 printing 5
# Thread 1 printing 3
# Thread 1 printing 4
# Thread 1 printing 5

# %% [markdown]
# # Part 2: Synchronization with Test_and_set
#
# Objective: Demonstrate the use of Test_and_set to prevent race conditions when multiple processes or threads access a shared resource (e.g., a counter).
#
# Steps:
# 1. Create a shared counter variable.
# 2. Spawn multiple threads or processes that increment the counter 100 times.
# 3. Without synchronization, print the counter value at the end to observe the race condition.
# 4. Implement Test_and_set to synchronize access to the shared counter and ensure the correct result.

# %%
import contextlib
import threading
import time

counter = 0

def increment(context):
    global counter
    for _ in range(100):
        with context:
            current = counter
            time.sleep(0.01) # workload
            counter = current + 1

def test(synchronized):
    global counter
    counter = 0
    context = threading.Lock() if synchronized else contextlib.nullcontext()
    threads = [threading.Thread(target=increment, args=(context,)) for _ in range(10)]
    print(f"Testing with synchronized={synchronized}")

    for thread in threads:
        thread.start()
    for thread in threads:
        thread.join()

    print(f"Final counter value: {counter}")
    print(f"Expected value: 1000")


test(synchronized=False)
print()
test(synchronized=True)
# Out:
# Testing with synchronized=False
# Final counter value: 100
# Expected value: 1000
#
# Testing with synchronized=True
# Final counter value: 1000
# Expected value: 1000

# %% [markdown]
# # Part 3: Semaphores for Synchronization
#
# Objective: Use semaphores to synchronize access to a shared resource (e.g., a printer or database).
#
# Steps:
# 1. Create a semaphore initialized to 1 (binary semaphore).
# 2. Use the semaphore to control access to a critical section.
# 3. Spawn multiple processes or threads and use the semaphore to ensure mutual exclusion.

# %%
import threading
import time

semaphore = threading.Semaphore(1)
printer = []

def use_printer(name):
    for i in range(3):
        with semaphore:
            printer.append((name, i))
            time.sleep(0.01) # workload

threads = [threading.Thread(target=use_printer, args=(i,)) for i in range(3)]

for thread in threads:
    thread.start()
for thread in threads:
    thread.join()

for name, job in printer:
    print(f"Thread {name} used the printer for job {job}")
# Out:
# Thread 0 used the printer for job 0
# Thread 0 used the printer for job 1
# Thread 0 used the printer for job 2
# Thread 1 used the printer for job 0
# Thread 1 used the printer for job 1
# Thread 1 used the printer for job 2
# Thread 2 used the printer for job 0
# Thread 2 used the printer for job 1
# Thread 2 used the printer for job 2

# %% [markdown]
# # Part 4: Dining Philosophers Problem
#
# Objective: Implement a basic version of the Dining Philosophers Problem where five philosophers try to eat by picking up two chopsticks.
#
# Steps:
# 1. Create a program that simulates five philosophers sitting at a table.
# 2. Each philosopher alternates between thinking and eating.
# 3. Each philosopher needs to pick up two chopsticks before eating.
# 4. Try to implement a simple synchronization and observe the results.
# 5. Without synchronization, observe the potential problems like deadlock or race conditions.

# %%
import contextlib
import threading
import time

NUM_PHILOSOPHERS = 5
chopsticks = [threading.Lock() for _ in range(NUM_PHILOSOPHERS)]

def philosopher(name, context):
    print(f"Philosopher {name} thinking")
    first = name
    second = (name + 1) % NUM_PHILOSOPHERS
    
    with context:
        print(f"Philosopher {name} picking up chopstick {first}...")
        chopsticks[first].acquire()
    
        time.sleep(0.05) # pickup interval
    
        print(f"Philosopher {name} picking up chopstick {second}...")
        chopsticks[second].acquire()
    
        print(f"Philosopher {name} finished")
        chopsticks[first].release()
        chopsticks[second].release()

def test(synchronized):
    print(f"Testing with synchronized={synchronized}")
    context = threading.Semaphore(NUM_PHILOSOPHERS - 1) if synchronized else contextlib.nullcontext()
    threads = [threading.Thread(target=philosopher, args=(name, context)) for name in range(NUM_PHILOSOPHERS)]

    for thread in threads:
        thread.start()
    for thread in threads:
        thread.join(timeout=1)

test(synchronized=True)
print()
test(synchronized=False)
# Out:
# Testing with synchronized=True
# Philosopher 0 thinking
# Philosopher 0 picking up chopstick 0...
# Philosopher 1 thinking
# Philosopher 1 picking up chopstick 1...
# Philosopher 2 thinking
# Philosopher 2 picking up chopstick 2...
# Philosopher 3 thinking
# Philosopher 3 picking up chopstick 3...
# Philosopher 4 thinking
# Philosopher 0 picking up chopstick 1...
# Philosopher 1 picking up chopstick 2...
# Philosopher 2 picking up chopstick 3...
# Philosopher 3 picking up chopstick 4...
# Philosopher 3 finished
# Philosopher 2 finished
# Philosopher 4 picking up chopstick 4...
# Philosopher 1 finished
# Philosopher 0 finished
# Philosopher 4 picking up chopstick 0...
# Philosopher 4 finished
#
# Testing with synchronized=False
# Philosopher 0 thinking
# Philosopher 0 picking up chopstick 0...
# Philosopher 1 thinking
# Philosopher 1 picking up chopstick 1...
# Philosopher 2 thinking
# Philosopher 2 picking up chopstick 2...
# Philosopher 3 thinking
# Philosopher 3 picking up chopstick 3...
# Philosopher 4 thinking
# Philosopher 4 picking up chopstick 4...
# Philosopher 0 picking up chopstick 1...
# Philosopher 1 picking up chopstick 2...
# Philosopher 2 picking up chopstick 3...
# Philosopher 3 picking up chopstick 4...
# Philosopher 4 picking up chopstick 0...
